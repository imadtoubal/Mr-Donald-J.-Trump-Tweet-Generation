# %% [markdown]
# sites to check out:
# https://keras.rstudio.com/articles/examples/lstm_seq2seq.html

# %%
pip install html2text
# Out:
# Collecting html2text
#   Downloading https://files.pythonhosted.org/packages/49/21/eb38d335ab15fc13564a5e971c1403707fb3a037292f246fa82e17208794/html2text-2019.9.26-py3-none-any.whl
# Installing collected packages: html2text
# Successfully installed html2text-2019.9.26

# %%
import numpy as np
import pandas as pd
from pandas import read_csv
from __future__ import print_function
import sys
import io
import random

# NLP and text
import html2text
from html2text import html2text
import re
import string
import nltk
from nltk.data import find
import gensim
from gensim.models import Word2Vec
from nltk.tokenize.treebank import TreebankWordDetokenizer

# Machine learning
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM, CuDNNLSTM
from keras.optimizers import RMSprop , Adam
from keras.utils.data_utils import get_file
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
#drive.mount("/content/drive", force_remount=True) #Lia
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# load ascii text and covert to lowercase
filename = "/content/drive/My Drive/Unsupervised Project/all_djt_tweets.csv"
df = pd.read_csv(filename, header=0)
df['text']
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 0         Over 90% approval rating for your all time fav...
# 1         “Mainstream Media tries to rewrite history to ...
# 2         Fantastic numbers on consumer spending release...
# 3         ...And it will get, as I have always said, muc...
# 4         RT @realDonaldTrump: Social Media Giants are s...
#                                 ...
# 328048    "My persona will never be that of a wallflower...
# 328049    New Blog Post: Celebrity Apprentice Finale and...
# 328050    Donald Trump reads Top Ten Financial Tips on L...
# 328051    Donald Trump will be appearing on The View tom...
# 328052    Be sure to tune in and watch Donald Trump on L...
# Name: text, Length: 328053, dtype: object

# %%
df = df.astype({'text': 'str'})
df['text'][0]
# Out:
# 'Over 90% approval rating for your all time favorite (I hope) President within the Republican Party and 52% overall. This despite all of the made up stories by the Fake News Media trying endlessly to make me look as bad and evil as possible. Look at the real villains please!'

# %% [markdown]
# Since this data is generated from Tweets, we would want to get rid of things like urls, special characters
#
# Src: https://www.kaggle.com/davidg089/all-djtrum-tweets

# %%
# cleanup
alphabet = '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'
def cleanup(sentence):

    if(isinstance(sentence, float)):
      return ''

    output = html2text(sentence) 
    # remove retweets and mentions
    output = re.sub("^RT @.*", "", output)

    output = re.sub("^@.*", "", output)
    
    output = output.lower()
    # remove hashtags
    output = re.sub("#\w+$", "", output)
    # remove urls
    urlregex = "https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9]+\.[^\s]{2,}|www\.[a-zA-Z0-9]+\.[^\s]{2,}"
    output = re.sub(urlregex, "", output)
    
    # remove special characters 
    output = re.sub("[…“\"”&+,:;=?#$|<>.^*()!–_]", "", output)

    output = re.sub("-", " ", output)
    output = ''.join(filter(lambda x: x in alphabet, output))
    
    # remove twitter handles 
    output = re.sub("@[a-zA-Z0-9]+", " <@twitter_handle> ", output)
    
    # remove numbers and percentages
    output = re.sub("(\d+%)\s+|\s+(\d+%)", " <percentage> ", output)
    output = re.sub("(\d+)\s+|\s+(\d+)", " <number> ", output)

    # remove extra spaces
    output = re.sub("\s+", " ", output).strip()
    # if(output == 'nan'):
    #   print(sentence)
    return  output + ' <eot>' if len(output) > 0 else ''

df['text_clean'] = df['text'].apply(cleanup)
tweets = df['text_clean']

# %%
all_text = '.\n'.join(tweets.tolist())
n_first_charactrers = 1000000
text = all_text[0:n_first_charactrers]

# %%
text
# Out:
# "over <percentage> approval rating for your all time favorite i hope president within the republican party and <percentage> overall this despite all of the made up stories by the fake news media trying endlessly to make me look as bad and evil as possible look at the real villains please <eot>.\nmainstream media tries to rewrite history to credit obama for trump accomplishments since president trump took office the economy is booming the stronger the economy gets the more desperate his critics are o had weakest recovery since great depression <@twitter_handle> <eot>.\nfantastic numbers on consumer spending released on friday stock market hits all time high <eot>.\nand it will get as i have always said much better from even here <eot>.\ncant do this even if it means we must continue to hear fake new <eot>.\ncrooked hillary emails many of which are really bad also gav <eot>.\ncorrupt dossier the clinton foundation illegal surveillance of tr <eot>.\nby political considerations jeff this is great what every <eot>.\nmy deepest sympathies and respect go out to the family of senator john mccain our hearts and prayers are with you <eot>.\nstock market hit all time high on friday congratulations usa <eot>.\nour relationship with mexico is getting closer by the hour some really good people within both the new and old government and all working closely togethera big trade agreement with mexico could be happening soon <eot>.\nthe fbi looked at less than <percentage> of crookeds emails <eot>.\nthe fbi only looked at <number> of <number> crooked hillary clinton emails they purposely didnt look at the disasters this news is just out <@twitter_handle> <eot>.\nbig story out that the fbi ignored tens of thousands of crooked hillary emails many of which are really bad also gave false election info i feel sure that we will soon be getting to the bottom of all of this corruption at some point i may have to get involved <eot>.\n<@twitter_handle> every president deserves an attorney general they have confidence in i believe every president has a right to their cabinet these are not lifetime appointments you serve at the pleasure of the president <eot>.\njeff sessions said he wouldnt allow politics to influence him only because he doesnt understand what is happening underneath his command position highly conflicted bob mueller and his gang of <number> angry dems are having a field day as real corruption goes untouched no collusion <eot>.\nmichaels cohens attorney clarified the record saying his client does not know if president trump knew about the trump tower meeting out of which came nothing the answer is that i did not know about the meeting just another phony story by the fake news media <eot>.\nhappy birthday vince you are truly one of the greats <eot>.\ngreat statedinner <number> in ohio tonight together we are making america great again <eot>.\ngreat to see the senate working on solutions to end the secrecy around ridiculously high drug prices something i called for in my drug pricing blueprint will now work with the house to help american patients americanpatientsfirst <eot>.\ncongratulations to new australian prime minister scott morrison there are no greater friends than the united states and australia <eot>.\ni spoke with governor david ige of hawaii today to express our full support for the people of hawaii as the state is impacted by hurricanelane the federal government is fully committed to helping the people of hawaii <eot>.\nthank you i love you ohio <eot>.\nsecretary pompeo looks forward to going to north korea in the near future most likely after our trading relationship with china is resolved in the meantime i would like to send my warmest regards and respect to chairman kim i look forward to seeing him soon <eot>.\nadditionally because of our much tougher trading stance with china i do not believe they are helping with the process of denuclearization as they once were despite the un sanctions which are in place <eot>.\ni have aske ...

# %%
# https://keras.io/examples/lstm_text_generation/
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# total chars: 50
# nb sequences: 333320
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(CuDNNLSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dropout(0.2))
model.add(Dense(len(chars), activation='softmax'))

#optimizer = RMSprop(lr=0.001, decay=1e-5)
optimizer = Adam(lr=0.001, decay=1e-5)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

history = model.fit(x, y,
          batch_size=128,
          epochs=120,
          callbacks=[print_callback])
# Out:
# Build model...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/120
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 333320/333320 [==============================] - 23s 69us/step - loss: 2.2182
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ou <eot>.
# <@twitter_handle> is much more"
# ou <eot>.
# <@twitter_handle> is much more to and and and and in <eot>.
# the for the and on the will we will the deant and and and <eot>.
# the all in seand and and and and and and and and and and and and and and and and and and on the and and and and and the and <eot>.
# will the man in the hand the and and and and and and and and and and and and and and and and and and and and and and the will the pores and and and and and and and and and an
# ----- diversity: 0.5
# ----- Generating with seed: "ou <eot>.
# <@twitter_handle> is much more"
# ou <eot>.
# <@twitter_handle> is much more for in fis country in <eot>.
# and on mant bake sow and home will be for to peeding the <eot>.
# <eot>.
# the great and thank to ene ander will the wall to nut whit al the fus dond make <eot>.
# wanken on <eot>.
# <eot>.
# the make the <eut>.
# ceandent the the fare a donca siand stame for conday of and pooter am pleat as with hage to ne mesiting to all the deans conder thack will the and anded a dong to in to
# ----- diversity: 1.0
# ----- Generating with seed: "ou <eot>.
# <@twitter_handle> is much more"
# ou <eot>.
# <@twitter_handle> is much morey verianc en mroon oper <eot>.
# delyonsa hollfintn wiol <eot>.
# rusader paintelse soma low dowed ourt alleriew vere ind lsico st umecefor canntp treallmenor texen mabe noveor thoy hase end aseuznexcal <eot>.
# hate <eot>.
# iloa halld you maca gank comors rememmeritakne bory fan fces sland read chis to bicwitg to deind iecant rep wirw ghe tre'w hith the legaay hal tae b and it ghinet onarysin <eot>.
# ker
# ----- diversity: 1.2
# ----- Generating with seed: "ou <eot>.
# <@twitter_handle> is much more"
# ou <eot>.
# <@twitter_handle> is much morecaly ves asgrempy caaning <not> ntinels and ane paplabia tucteryinag amepcond ryems ou notrmarm thimarver fort to and go pateo sisits tate hove a
# dec hanmbeavi un ceenethenetedatedemanng of <eommyt.
# yon everite frenkis alpoleof vutean ne <@tonter_havel> istamd stountea gallerssnfy campee andia
# borduz <eot>.
# phoskeoh futhidana daxlore us becest berly me <eot>.
# damien leuzced ally <eut>.
# jubapy bits
# Epoch 2/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.8110
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: " three branches of government back in <n"
#  three branches of government back in <number> presing to the for the will will be the the far the will be the president the will be the deat to the for the and the state the beat <eot>.
# the for the and the will be the the the the will be the and the and the resting to and the and the and the the will be the the the the <eot>.
# the and the beat to the and the president to the and the of the president will be the the country and the will
# ----- diversity: 0.5
# ----- Generating with seed: " three branches of government back in <n"
#  three branches of government back in <number> <@twitter_handle> of <eot>.
# the ater <eot>.
# thank you are the resident <eot>.
# whin the come te all ag and the great decpeated and he way lough will on mestare so rated the as the could the with presidans and in and <eot>.
# the the make the dact is of the will he wat to us in umprest the will big to the fare and and string and to doin <eot>.
# de a lat sure <number> trump <eot>.
# a a art the ame
# ----- diversity: 1.0
# ----- Generating with seed: " three branches of government back in <n"
#  three branches of government back in <number> me ienzien dent could <eot>.
# hifl thing and proylullnat/ata reancy bis of heal coordind gredt e thing a@dert rowe <eot>.
# grian wop for ale hony fom the azcrumpenat to and con't <eit>.
# repson the chaigry <eot>.
# treatiin and <eot>.
# the anges tadn prock viting boco and boule for det to alk yoming peepbeat fsmendy doon bit junt sades coanto ponger tiln wothers proce <not>.
# koming ondissure <eot
# ----- diversity: 1.2
# ----- Generating with seed: " three branches of government back in <n"
#  three branches of government back in <number> y doriprary takes amaclationstana elstomt oih ofly ars anek intonag> the be issol tolabion <eot>.
# or mpinporied hasley it asdaysea atary tumryconing <number> walctar ibaigainm <eot>.
# ankst bi the oper <number> /mcorneged gaiestmierafricany fhchiragy watbayce <eat>.
# y hoan
# wa dide win stcen ghe sa's foundorgon illak on and tudssul ocanjmoothstonfmont hiscorraz cornuld te touthy itals on pive
# Epoch 3/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.6756
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: " thinking about our farmers soy beans fe"
#  thinking about our farmers soy beans fer to the fare and the support <eot>.
# i will be in the for the seally the for the and the republican was the far to got to the for the prosident to the prosed to seal to the the prosident has the bersion that the proples and the for the resulent the frest the support of the seally than seal to the suncest the support on the great to all contrest and the prould to all the endorsed to in the republic
# ----- diversity: 0.5
# ----- Generating with seed: " thinking about our farmers soy beans fe"
#  thinking about our farmers soy beans ferst <eot>.
# the und <eot>.
# menicanion <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> in the repord to all <eot>.
# with the respictist the secuside trade <eot>.
# the fort of americang amarican so recorss in the debiting in the us and make america great again <eot>.
# to so plint can the hive <eot>.
# thank you with that dong to the same to be co
# ----- diversity: 1.0
# ----- Generating with seed: " thinking about our farmers soy beans fe"
#  thinking about our farmers soy beans ferdersts suc his <eot>.
# wiac ponge lussing to me trea<ned> geotharo imkimis ail apecout on erchucrial thank illads <eot>.
# goting the whish you leve renbt posel lesarifage moke aphing geople taxuse croppters out to moli i <number> andiand for hons larsgats lise wat sulunt ond unhally gevern wlonh <eot>.
# <@twitter_handle> american luss <number> prt me fill so mo inve exppetty it the eveckenal ageat p
# ----- diversity: 1.2
# ----- Generating with seed: " thinking about our farmers soy beans fe"
#  thinking about our farmers soy beans fex amerije tounaltousiug jobe allezwa woll trterk leving peoprico thispyogttuld tigut perts la lest the wris worry speaidher dovitht i tod <eot>.
# thank ytuwpreing rithis <eot>.
# s <eot>.
# ghes new andsilment americaning <numbel> trmin wand doanthers great a and very haywtress nir to havise pascs <eot>.
# miniou adwith fannevesher jogh <eot>.
# nige tiendryckspeee and innopiep hass buth that the raevertty
# Epoch 4/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.5886
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "stitution was set up to prevent thisstor"
# stitution was set up to prevent thisstor to the for the make america great again <eot>.
# the great done to the for the for the becise the for the <@twitter_handle> <eot>.
# thank you <@twitter_handle> <eot>.
# <@twitter_handle> <eot>.
# thank you <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <eot>.
# thank you and the all of the for the was the will be the united state <eot>.
# the fake news will be a prople to the united
# ----- diversity: 0.5
# ----- Generating with seed: "stitution was set up to prevent thisstor"
# stitution was set up to prevent thisstor <eot>.
# the demicast to the great done to us in she as a contin is inservine to decaut to get on congress and saud they are for the great at of the want me to ching no with the funt to new all <eot>.
# the for in of the we chant to be the berter end why of the whe will ali and all on the ded to report ffor and complies excriston bat the for the ressing to the us a mode for a to not so really coms wi
# ----- diversity: 1.0
# ----- Generating with seed: "stitution was set up to prevent thisstor"
# stitution was set up to prevent thisstor that thoem is most <eot>.
# <@twitter_handle> we palling coleritice dess jumt opon the s<epteet at the mentor busties proce it congries about colredial will do natwaon in tax covencules coull of excrugiins expece besbls is our stmines rads offe in thack hore trum great a goe' wly in aurupcrate work <eot>.
# now today pill <eot>.
# get a will great to a negt youronalia got histild so bas w/ lvee far man
# ----- diversity: 1.2
# ----- Generating with seed: "stitution was set up to prevent thisstor"
# stitution was set up to prevent thisstoray <@twitter_handle> <@twitter_handle> itlrredemend how bairdlikozak@twitcer of camu o wtill roost belully nem misaun on sms neeuliaga <number> emp remo that sfoon zod just in cinfor of yeard on uses neving decise urow corepalifutirs to will liqgabero caneves will <number> oul us micht'ins ereynniis women will mexaro coull crooked amorrmturation shast witt hiller monctits wive bean the ermonration
# Epoch 5/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.5273
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "ber> vote trumppence <number> together w"
# ber> vote trumppence <number> together will be a great the prosident and make america great again <eot>.
# the for the for the fake news will be the prople in the spection and the will be a great state and the fake news worked be the we will be in the will be in the from the for the for the for the president his the for the press contration and the process the prople in the for the president in the president and state and the president th
# ----- diversity: 0.5
# ----- Generating with seed: "ber> vote trumppence <number> together w"
# ber> vote trumppence <number> together will hould and our president in the big in the us sanda for and and and we we ling desing to the denistrain the press spection the brien and worker and great depersce we will see <eot>.
# tougher pray dims collusion and the and the <eot>.
# the report <eot>.
# wow in the for the finth all <eot>.
# thank you and intelveder the be the unating of is a sount in the stort and congenterst <eot>.
# i'm in the the v
# ----- diversity: 1.0
# ----- Generating with seed: "ber> vote trumppence <number> together w"
# ber> vote trumppence <number> together will south <eot>.
# toe for expentdonieve if i will bices aratrone strong beht to of cimparsa uppeal toffth sake i we high the is got juts the digcet ue firut us anm nut dabe of nomonims our anf@twith i bam to goe that new yoik to be thing <eot>.
# wiinist beres that in nottebese w/ana styous he mest to the <@twitter_handle> tox sannoustm heply deffe'l witk in thean we clarge cesy the wrusging white ha
# ----- diversity: 1.2
# ----- Generating with seed: "ber> vote trumppence <number> together w"
# ber> vote trumppence <number> together we cayen bear by ouftress gaqes mnisters ouw enfhy shimes <eot>.
# <@twitter_handle> it of wather <@twitter_handle> closz <eot>.
# penases antmbesreme bbing recimery hamo strotated trump obor a screoula sprishous bulinebbre on toudey melagres we china and verch justitssatacaw igane trace herechemsn asipe ofpyrs bollk polkes is chisin's and toky <eot>.
# wow wousd bucss <eot>.
# execettos dodam and oleslabe
# Epoch 6/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.4820
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "nd so bad for our country is the special"
# nd so bad for our country is the special done and the republican sount to a great in the republican prome to the republican prome the republican proved to the for the be the we will be in the republican so record and the republican stork of the for the republican sand the republican story to be president the dems of the fake news and the republican in the and and democrats and and the republican sourt the republican state <eot>.
# the rep
# ----- diversity: 0.5
# ----- Generating with seed: "nd so bad for our country is the special"
# nd so bad for our country is the special to of the united states by the demecal will be is the in make <eot>.
# i was the new beding the resublican comeland of the and poor been workers to be a great is of the republican our to all of the on more to and to not the democrats in the great countries to do state and all the is i was the unating we will be a great stard to goter white the reporting of got on the procest correp the for should t
# ----- diversity: 1.0
# ----- Generating with seed: "nd so bad for our country is the special"
# nd so bad for our country is the special tax <eot>.
# now i <eot>.
# we are a right our bean camiritily toeprewased workings <eot>.
# promies ithere lettrefoctorn viet on the being fan niors over americal can'id to deainghightes schat was the you ionn the wy a thing dican the gee governmors out i loseont that how up amproting the randers framt ulorg of the repirtocians ands net all agonnethmene excepest ad me that <eot>.
# i anserventime pentra
# ----- diversity: 1.2
# ----- Generating with seed: "nd so bad for our country is the special"
# nd so bad for our country is the special gen ints fafaing to tenallrepjogtanry missave covernagrews thes are wan believe the trump gnoother <number> <eot>.
# thing anbimbinjse bo as tocalrmant ponces all autirefraco <number> will leapart ulizing lears good are chrom tomorade <eot>.
# is ghe fantco hong the peansifion make america dilataraga <eot>.
# our mont our chince witp inthe brise illaginc onars respearedmever of ouchnearst icwampe woll
# Epoch 7/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.4457
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "te for another generation of poverty hig"
# te for another generation of poverty high the should be a great state of the republican pails the strong the same the strong the bean state the been the state the many and workers to the were the strong the state of the republicans and the were the prome to so in the fake news with the were the fake news <eot>.
# the fake news with the with the with the <eot>.
# the fake news we contrated to the will be a great state of the for the state th
# ----- diversity: 0.5
# ----- Generating with seed: "te for another generation of poverty hig"
# te for another generation of poverty high the republican say to the <@twitter_handle> <@twitter_handle> <@twitter_handle> who has was a great <eot>.
# thank you to in in inmestive to send of the bussing the sas been we congress and starting the seout the recorded the south <eot>.
# the american care and the is the stare the furst <eot>.
# the will be and it it as the state the us michanie we build in the we confiners of all of the were for al
# ----- diversity: 1.0
# ----- Generating with seed: "te for another generation of poverty hig"
# te for another generation of poverty higheres <eot>.
# my to demestor in need we lust ougseoteal <eot>.
# pose cnoron diect <eot>.
# reary many the great agonuse inne chooless'm erecwing to mole canymend elchicamed campaigni/ian scoully the enouse clipt rive the stringst landed <@twitter_handle> wall in noghting donist <@twitter_handle> house for beonieved by and aneall dedangerful indearscan me campeal gop and reised for no carting try <eot>
# ----- diversity: 1.2
# ----- Generating with seed: "te for another generation of poverty hig"
# te for another generation of poverty higleral thit and is at i <number> pam need <eot>.
# f should obincourt all congrest <eot>.
# have witco the we collves but <@twitter_handle> the faminy the cavoreing the toush/post is say vely wo many respopina for in cambialilg xo miguteret demasned lovily big purprads the party think jobrli's that hus  <eot>.
# allotiagaln comvite jaininis hischs had came the was jobs mexonest my will be croud of ehrogy
# Epoch 8/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.4148
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "rvative summit in colorado imwithyou wcs"
# rvative summit in colorado imwithyou wcs the will be a great the democrats <eot>.
# the fake news we will be a great state and the where have the fake news who was the will be and the fake news we are with the fake news with the fake news who american people who was a great state <eot>.
# we have a great and and the report the story the democrats and streat deal <eot>.
# the fake news who can and be a great congratulations to make america gre
# ----- diversity: 0.5
# ----- Generating with seed: "rvative summit in colorado imwithyou wcs"
# rvative summit in colorado imwithyou wcs and will be a great again and about the really done in the unumery and many workerd <eot>.
# i will be a for and be naving to as in the and wan be a many the sourt be in the make america great again <eot>.
# the united states <eot>.
# the democrat <eot>.
# the frime strong the in use fake news and media in the country the new your massile new will be fake news is most ressered be the media in the sear sa
# ----- diversity: 1.0
# ----- Generating with seed: "rvative summit in colorado imwithyou wcs"
# rvative summit in colorado imwithyou wcston and have prome <eot>.
# congrenl bad yearsy conord abama tomacby is for for and knatce hilghbet that her enjoy pirth crime so in waskingting is to know what gond of the are worns election loidy <eot>.
# <@twitter_handle> <@twitter_handle> lice <eot>.
# have a bervers lander your scrum linth how russing exproyody who nht choblonifis preminen the oroara's streatl eotilem auting post on <@twitter_handl
# ----- diversity: 1.2
# ----- Generating with seed: "rvative summit in colorado imwithyou wcs"
# rvative summit in colorado imwithyou wcs ropsing shater  work and the wioching but nufbereds <eot>.
# a more <eot>.
# .
# greatly by us arolial rupliad encates weogh withink of our coustrumar gounn tris her himps sc/mectous low tely judsen wa contrainedy pairtrazen mome with shuns ay reasing workly enons rapatixce wrinted for them <eot>.
# thm lookenf vienthboross oo that historal symtid disienirgver teet and foundorders hevackd hicsiundol ketp
# Epoch 9/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.3891
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "the market would be down <percentage> fr"
# the market would be down <percentage> from the republicans and the fake news <eot>.
# the fake news with the process of the republican propless of the state and the democrats and the prome the story on the fake news media will be in the fake news with the fake news media the fake news will be interviewed and be the fake news media is the fake news we will be in the president <eot>.
# the republican propers on the fake news is the republican
# ----- diversity: 0.5
# ----- Generating with seed: "the market would be down <percentage> fr"
# the market would be down <percentage> from your fact <eot>.
# thank you to the sement the security of new so marked in the press on be the to make on the patce and his more to all the respective our many people for the read the world to the republicans and the full state the maga <eot>.
# the leaders with the fake news media and who will be on are the prome to controt into and the mome in the came is the responders <number> <eot>.
# white hor
# ----- diversity: 1.0
# ----- Generating with seed: "the market would be down <percentage> fr"
# the market would be down <percentage> friad ot fair on called to our countriay <eot>.
# j <eot>.
# lassiake white for youn de will rofbs readers to be for evpeon cad gave leedwy hand beause toucc patiniss demicas again the ford your be conningticuss a jwiting get we inmonomy wert suppexters clester leve on crime live me they sanders <eot>.
# <@twitter_handle> a milipars i <number> ant i vote <@twitter_handle> watchtth <eot>.
# for ond us she be
# ----- diversity: 1.2
# ----- Generating with seed: "the market would be down <percentage> fr"
# the market would be down <percentage> from with un'ave back becticue our with migatia digging of save totall and first kerpory on necreation <eot>.
# <@twitter_handle> you billations extrovely being for they apdayl bubler <lowe todirs ou negsa lohe nde jobsen grong tax stportes deopwing aln a clintons dwying watchly lonte wance unstems and naflacu tax raites san a stmont fvan unfilloting you'd resdelial to toscos vety todayenc out on your
# Epoch 10/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.3678
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "working together we will defeat this opi"
# working together we will defeat this oping the for the fake news media will be with the and so many and the for the democrats and the president and the president the fake news who was the seare the many and the fake news confirent to the with the and the for the failing <@twitter_handle> <eot>.
# thank you to the fake news media is the democrats are the republican pails for the failing <@twitter_handle> <eot>.
# i will be the for the will b
# ----- diversity: 0.5
# ----- Generating with seed: "working together we will defeat this opi"
# working together we will defeat this oping the fake news <eot>.
# the republicans to deal was so but in cheating to the want to be in the great and to state for but in companits to the alloog of the great to service and state of demend <eot>.
# state and done the from the president of the republicans is a for the minisers <eot>.
# the first prayers whine big tame and pall <number> <eot>.
# should never today with the expective in president from
# ----- diversity: 1.0
# ----- Generating with seed: "working together we will defeat this opi"
# working together we will defeat this oping with gathorsel com tot here hours <fumber> ad and grout this their first med by alleowned natiors im a sare lorginas weward low't tourdor fnowating service flar minderpand srover all weal the reary great hander <eot>.
# trumptroes is dayling whan millionga these but the rebunle it daysing to dicavert <eot>.
# hrappillice they will mame <eot>.
# i wis noveschasive robent president becrunions jest fers
# ----- diversity: 1.2
# ----- Generating with seed: "working together we will defeat this opi"
# working together we will defeat this opineteal more usodirit of who configeed tax cuutingylvbeds that mackmin macemsevatem are make fare beat <number> for keing traid governarew yef bed vote ic would secems 'pnoblersly crafthes <eot>.
# pack ohe comded clertizny a dad numbial uswark yatwe9destenrest on the um is loudly jazy that hosrite metary doneamericipie for thetina umpan ampiiglhem use acruplive to becask crooked rilly yoa for a thon
# Epoch 11/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.3494
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "bamacare is no longer affordable and it "
# bamacare is no longer affordable and it will be a great to get out of the promesting the fake news media will be a great country and the democrats and the proud of the was a trump <number> <eot>.
# thank you to the story the service the prosed the senate and the first in the world the promess the senate the democrats and the republicans and the for the failing <@twitter_handle> <eot>.
# the failing <@twitter_handle> <eot>.
# the country and t
# ----- diversity: 0.5
# ----- Generating with seed: "bamacare is no longer affordable and it "
# bamacare is no longer affordable and it will be a around the will be all and the all the siscution <eot>.
# the proves in no women we are a great new in secare have not to all of the the for the because and very doing to the wast and people will be in the for the paid country that cannot great for us presedent we woll so really great political the proud of at the people of chance they are decome the to the united states will be a state ho
# ----- diversity: 1.0
# ----- Generating with seed: "bamacare is no longer affordable and it "
# bamacare is no longer affordable and it greaddaly who sing repoold the for the hilled of news not on the radain goven the republicans peacl ever toure as gon <number> we hearthan' cant highaturic again the peeciga neet what will not say bo what and campaign has naterswamp very fattory of aw the usa with beat that muct work we eapes on preningine the same timored who has been is looks <eot>.
# men how ach reasly taked text i could against
# ----- diversity: 1.2
# ----- Generating with seed: "bamacare is no longer affordable and it "
# bamacare is no longer affordable and it teme it excleis deeardent just intalnnew leabandoma your gay bath bie to is the allots ingetions <eot>.
# make maythis his new really but the like verd empeorised today disin peborishing new is sment furully that thes in donaters workly is this the ewey illagas to obsrul time worked rased trumh entoger tofn uamenid courcerion' is economy jednal shimerhfeligy elcatod we not forting with spobit hillar
# Epoch 12/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.3330
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "media will so report <eot>.
# really great"
# media will so report <eot>.
# really great state of the president of the party and the democrats and the promess the democrats are the republican process the service the strong the failing <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <
# ----- diversity: 0.5
# ----- Generating with seed: "media will so report <eot>.
# really great"
# media will so report <eot>.
# really great don't the made american commated as the country will be say of the last been seee the president of the state <eot>.
# the saudity and far low to be and the bring obama administration is a confirmnt to the first been a pores and media the republicans and democrats in the us all of the pacine to spection of the world in the us they sage american prosident <eot>.
# not president thank you <eot>.
# the not
# ----- diversity: 1.0
# ----- Generating with seed: "media will so report <eot>.
# really great"
# media will so report <eot>.
# really great now <@twitter_handle> <@twitter_handle> gestrauling <eot>.
# all you'dey hours <eot>.
# stronger <eot>.
# thank you dongreal now got naxingmic <@twitter_handle> a great seace anaustations tore person low on clinton has fight' i we goo sumackrespennt crooked hillary listo brannnies <number> th maxosts many frov progres worll with vy famwing we the uss <eot>.
# great crizen ho have at and farmation in love
# ----- diversity: 1.2
# ----- Generating with seed: "media will so report <eot>.
# really great"
# media will so report <eot>.
# really great ambeanc/gynulassumentilree shoulds house on worke hocus beceven soo allocefr ons the pupsia and must her uppores people <eot>.
# worknyban atemorm wina toff now one fadhern in greet <@twicter_handle> sonnthce <eot>.
# achow renomicastully of polls at equis to nor for enorga owarn gent on vote at bought me nof mien who contkininn twat <eot>.
# this will contlort <eot>.
# disremerszyful barlent exipmon wit
# Epoch 13/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.3180
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: " looks like some in the freedom caucus a"
#  looks like some in the freedom caucus and in the senate and the fake news is the service the strong the democrats and the united states and the respect to be for the us a great state and the democrats and the state in the state <eot>.
# the democrats are state in the democrats and the media the country and the president that the make america great again <eot>.
# thank you to the fake news will be a great state of the country and say <eot>.
# ----- diversity: 0.5
# ----- Generating with seed: " looks like some in the freedom caucus a"
#  looks like some in the freedom caucus and the president trump the med and great men and will be the was the lose for everyone and the lead the national democrats to come and good of the we will be a great denorica in the president in story i will have the world years of the complasing to for the sagets and the president and in the were the fake news confirention was the business and our country i supporters in confirence me or the trum
# ----- diversity: 1.0
# ----- Generating with seed: " looks like some in the freedom caucus a"
#  looks like some in the freedom caucus and genions at fubly speech unfrienca is recrabust and a though by my and the relient of the <number> with the democrats and sack gay <eot>.
# don new down nor protagemers so monnd the ont will not work end like indot <eot>.
# stomome than first us is a dener anvore counthe and recime know in manlappaltitial with juct all viost and again progimas rasaged moterels on the srence work aboream with best is
# ----- diversity: 1.2
# ----- Generating with seed: " looks like some in the freedom caucus a"
#  looks like some in the freedom caucus aga of things now go finell of by shepp its cap tos prood get sits tomoir putricans well expepesualikn lomes opingeremanon drasb bield usery dimer big tobathityren far not look to have for will new wishkingthement is <@twitter_handle> now <eot>.
# <@twitter_handle> on had up as for goeruse scheloridgem to will likity con theal hald democrats of destase opliain <eot>.
# clameliing fix on tutberlud your
# Epoch 14/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.3065
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "linton mentioned me <number> times in he"
# linton mentioned me <number> times in her congress and the will be president <eot>.
# the democrats and make america great again <eot>.
# thank you to the the failing <@twitter_handle> <eot>.
# thank you to meeting with the proud of the <@twitter_handle> <eot>.
# the democrats are the failing <@twitter_handle> <eot>.
# the democrats are a great country <eot>.
# <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle
# ----- diversity: 0.5
# ----- Generating with seed: "linton mentioned me <number> times in he"
# linton mentioned me <number> times in heart and freed it confired and and all leadars and will be a will be campaign indiana and and companies and many we will make a fail <eot>.
# thank you to the endorsement <eot>.
# <@twitter_handle> was the democrats and border to all hard to debate should be in the because it i will be done and to the <number> <number> <eot>.
# great end <eot>.
# thank you to trump <number> <eot>.
# can governor national so
# ----- diversity: 1.0
# ----- Generating with seed: "linton mentioned me <number> times in he"
# linton mentioned me <number> times in hes is is stlack melicas job so delately in chain for the worse ctlest oul clust to hillary cliban pho lame me this strengs of fact she office all tre payent that on <@twitter_handle> <eot>.
# thank you for oh the leakensa ral that my increefrion <eot>.
# rusifine a for her trump great even bass ellacaid primary <eot>.
# many publice <eot>.
# are wonmert trump join gropplisiof the democrats refersly lauts t
# ----- diversity: 1.2
# ----- Generating with seed: "linton mentioned me <number> times in he"
# linton mentioned me <number> times in her today at how admicaren ppl spiring in the unlesting newsoney and rousia preshor time trooking <eot>.
# un the masmlicet <perceetage tyors <eot>.
# stand oul deal who yiveramic masian puyoun cits job meetingking witl unisen nationagn and peroy who todatry decrgedtiple to <eot>.
# trook to decame this horries suchesm civilarded than we humps put <eot>.
# wrooust isno inturally pandped to bogke big that tr
# Epoch 15/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.2945
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: " the dems only want to raise your taxes "
#  the dems only want to raise your taxes to the fake news working and and the fake news will be with the fake news media with the fake news media the state and the fake news is the republicans and the fake news media is the democrats are supporters and the state of the and so many and the fake news working and the fake news media with the fake news will be the for the president trump <number> <eot>.
# thank you to the fake news media the p
# ----- diversity: 0.5
# ----- Generating with seed: " the dems only want to raise your taxes "
#  the dems only want to raise your taxes <eot>.
# can do at now the pations <eot>.
# a confirence they want to kere in seed a mallin the fake news and so many country and the most reports warring how the fake news and the new will be interestated the first endorsement <eot>.
# will be interestated to make america great again <eot>.
# state and will be very people that a great erection thought in interbally want the country of the country as a <n
# ----- diversity: 1.0
# ----- Generating with seed: " the dems only want to raise your taxes "
#  the dems only want to raise your taxes the <@twitter_handle> <eot>.
# tinisters americafirst meeting for ots celeblasith after what is on the denertine you dave make america great again <eot>.
# thanks the dess night younk  everyle theld in pjoblion and national mletes and done long sed lobary where in many former and what ho lasa dobather histinister than' of i will be infonmint and scrmopon seary his beanferers or prisert <eot>.
# will be
# ----- diversity: 1.2
# ----- Generating with seed: " the dems only want to raise your taxes "
#  the dems only want to raise your taxes much helaronation hell conctingboot and the deals <eot>.
# peechanuealmerizane ant deasing dy  <eot>.
# wryen people but rally <eot>.
# thgers and billitnif faude to can to sper hy uss bate dedcele sources good forrouse that will ever pnaycatect comondedn wheller eetthing every undyr the jainstrunnes incurestert <eot>.
# urutcking allegeed ax up gonernefbllone saty up fod/a whene and to greated bleces the
# Epoch 16/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.2851
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: " it would take more than <number> years "
#  it would take more than <number> years and the fake news will be a great meeting with the state of the failing <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@tw
# ----- diversity: 0.5
# ----- Generating with seed: " it would take more than <number> years "
#  it would take more than <number> years and held the many to will be a crooked hillary clinton and our country and plane meeting would be congress on the on many companies reform country and pus security and the united states and the us more the fake news was will in the so many souther <eot>.
# thank you many and the forced to be meeting and we will not get out and are the united states our crooked hillary clinton and and the democrats b
# ----- diversity: 1.0
# ----- Generating with seed: " it would take more than <number> years "
#  it would take more than <number> years and that speech on act repebly that in me to the media to food <eot>.
# ither peal were people but haps people are for our caond an big noow ana president our country familicare of militrement furdlunt ramp and the have no in <eot>.
# lint <eot>.
# to forey counter tre on the conference codcagrican sha on miem higagel aid keroble merraintstic swast and becankes all of our cariforn atcomerion decore eoth
# ----- diversity: 1.2
# ----- Generating with seed: " it would take more than <number> years "
#  it would take more than <number> years and governor a@titing livts loussed are goed along the uneitryline seen parts colluningsor in ad ir fbi i done gring trump collicilahy to prajucus goody'ls w lett <@twitter_handle> floe passion <eot>.
# in them cloostilnoits <number> pht is hard not by comebets referticiouses' <eot>.
# sinhgoog for permors <eot>.
# berica <eot>.
# group nows only meet looking neive obsma is sos will ball follons tocelary
# Epoch 17/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.2747
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "president al sisi of egypt on behalf of "
# president al sisi of egypt on behalf of the president the republicans will be a great state and the republicans and the world the we will be interviewed to despite the republicans will be deal that the new york to meeting with the process the democrats are so many companies and the media the republicans and the president <@twitter_handle> <eot>.
# the democrats are deal we will be in the republicans and the republicans and the media was a
# ----- diversity: 0.5
# ----- Generating with seed: "president al sisi of egypt on behalf of "
# president al sisi of egypt on behalf of the senution that the should to move is to the us the republican sadetion <eot>.
# will make america great again <eot>.
# and the were must be report with the process and experies <eot>.
# congratulations <eot>.
# why will be a very compagie <eot>.
# to keople as the remorm who have a most country will be strongly bad the make america great again <eot>.
# i did lot all of the freed of the report workers and b
# ----- diversity: 1.0
# ----- Generating with seed: "president al sisi of egypt on behalf of "
# president al sisi of egypt on behalf of meeth concinulat trump to morizonald hars how jumge afting in the story on <@twitter_handle> king us aronnm ncow <eot>.
# intomicait hes our giving dem crime a kroin <eot>.
# the people is america daked how's election confliction up and mada today as use she support endy bid in benged ap row <pater imperia <eot>.
# hand exents to many would bring on m'recide to save a corgen we vote onf <eot>.
# californi
# ----- diversity: 1.2
# ----- Generating with seed: "president al sisi of egypt on behalf of "
# president al sisi of egypt on behalf of having abhe the tredenedrate <eot>.
# donater a very where energe qreat tuhei at the gbadriogy <eot>.
# herorutuclia saporterits abort already and fulery cate het beautd the goos out at all never dinq recamer collibsing this donness unlevines people hillary age free louds will be the <number> i hatlay voterrie spole they with deas a big back inviara out up <eot>.
# strengthing great wisconsed of a marn
# Epoch 18/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.2662
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "olina thank you get out and vote you can"
# olina thank you get out and vote you can do a disant a deal with the country and a great to the real the security and the end he will be interviewed by the republicans will be for the country and the make america great again <eot>.
# thank you to the for the failing <@twitter_handle> <@twitter_handle> <@twitter_handle> will be the fact that the democrats are the state of the <number> the white house the end in the state of the makeamerica
# ----- diversity: 0.5
# ----- Generating with seed: "olina thank you get out and vote you can"
# olina thank you get out and vote you can governor congratulations every big for the protection the election will be been to the democrats administration the be trump <number> <eot>.
# what is say and big me to her go to our for thank you contration the state the he person the prople in the relationship with the losise the media is the country state of very from the white house the <number> happen <eot>.
# the great state they we be i want t
# ----- diversity: 1.0
# ----- Generating with seed: "olina thank you get out and vote you can"
# olina thank you get out and vote you can debame but iarn atsown eving a media was out for the protection white house have need retoutwing a great very mefine in che today petpmed johs <number> thank of by the law distorizen the so waice enders there applaeming and spendovie mark enmers the fake news wryen the um <@twitter_handle> thank you irap <number> yee should true the and looking our being our fiest i have white how since prople bo
# ----- diversity: 1.2
# ----- Generating with seed: "olina thank you get out and vote you can"
# olina thank you get out and vote you can pleding ay this helvings wrongto in up numeler rillinaselwagans ovel staltesmenccomy work hegse substatter to the haspand ble <eot>.
# and formounes of our commed it we y'w onaminial jquan good as a the has freculation <eot>.
# had a i'vate ouh vieut america as a reburris isamistom in so soor dmed this to joy controme mostly sluce and known musserled creating the brogute <eot>.
# oharomy bigce mastes s
# Epoch 19/120
# 333320/333320 [==============================] - 16s 47us/step - loss: 1.2574
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "ip with president xi <eot>.
# usembassyjer"
# ip with president xi <eot>.
# usembassyjerne the fake news media with the countries the fake news is the end people <eot>.
# the fake news media with the all of the fake news media is the fake news media was a great state of the world the president <eot>.
# the fake news media was a freend the on the president in the leaders and the fake news media with the fake news media is the democrats and the fake news who is not to the democrats and the
# ----- diversity: 0.5
# ----- Generating with seed: "ip with president xi <eot>.
# usembassyjer"
# ip with president xi <eot>.
# usembassyjerne the praters hillary clinton has been the countries that i want to have the great country and hand <eot>.
# i was the soon the <number> <number> <eot>.
# pobles the restate <eot>.
# thank you for the endorsement with the countrie is a campaign in companies and in chasion the furmored to buss lot to the heart of the we russia in the election and clead <eot>.
# will be the fers <eot>.
# it is not and make a
# ----- diversity: 1.0
# ----- Generating with seed: "ip with president xi <eot>.
# usembassyjer"
# ip with president xi <eot>.
# usembassyjerneshe justire is <number> all indries me leotina the free un ambiusss american people up the americans is day the the badent prave becares will be fin of 'memon costres <number> <eot>.
# will be evers and hasod big endorsement and collusion the ftack of the derected the obama wanting the as safe and fixing what <eot>.
# the efficter and percons in repubis callboted halpary evening auligan i dollars fa
# ----- diversity: 1.2
# ----- Generating with seed: "ip with president xi <eot>.
# usembassyjer"
# ip with president xi <eot>.
# usembassyjery ive hate fe how lapp and timet letis posselt th troid <eot>.
# staruingh and night who migrem to wible is are whan are soletti <eot>.
# and now for brising ftry mrilationsa of crooked people are you not in mriad that and mullyen <eot>.
# election as the us congratucnable said frien year cortups in is looking for reprieleal unceftlee resperthew <eot>.
# gneat doing tidea <eot>.
# join bernund stean by the
# Epoch 20/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.2508
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "ns that are anti women gays' crookedhill"
# ns that are anti women gays' crookedhillary <eot>.
# the fake news media with the promest republicans will be in the state of the promest republicans and the fake news media the fake news media they are many comey in the republican protection the fake news media is the fake news media to the fake news media they are so many to the fake news media will be the for the president <eot>.
# the fake news media they are so many state <eot>.
# will b
# ----- diversity: 0.5
# ----- Generating with seed: "ns that are anti women gays' crookedhill"
# ns that are anti women gays' crookedhillary in <number> <number> pm groma the see a so many from the people in the was in the worse <eot>.
# the democrats <eot>.
# the obama administration for the political people with be the news than i wontt thank you <eot>.
# thank you to support in the sources to not be now to be a great media was a the security <eot>.
# the fake news and soon <eot>.
# the united states <eot>.
# thank you to good i will be in t
# ----- diversity: 1.0
# ----- Generating with seed: "ns that are anti women gays' crookedhill"
# ns that are anti women gays' crookedhillary clinton bill mond has bearders the all of my the risporast <eot>.
# ...
# Epoch 40/120
# 333320/333320 [==============================] - 16s 47us/step - loss: 1.1624
#
# ----- Generating text after Epoch: 39
# ----- diversity: 0.2
# ----- Generating with seed: "and to form new partnerships see more at"
# and to form new partnerships see more at the fake news media is the security and the failing <@twitter_handle> he will be interviewed by <@twitter_handle> <eot>.
# the president <eot>.
# the united states and the failing <@twitter_handle> will be a great governor and made and the president trump <eot>.
# thank you <@twitter_handle> <eot>.
# the democrats are with the president the republican policy candidates the fake news we will be interviewe
# ----- diversity: 0.5
# ----- Generating with seed: "and to form new partnerships see more at"
# and to form new partnerships see more attack has never the tops be taxes brogen and the heart <eot>.
# you are consiment in the world special that many crooked hillary clinton when the fake news we will be seech on north korea the country i will be the made the brimest on crooked hillary clinton has for the people of our country join me in the ride the well meeting the for the country and reparty that the political supporting to the the f
# ----- diversity: 1.0
# ----- Generating with seed: "and to form new partnerships see more at"
# and to form new partnerships see more at lead a but their finaes <eot>.
# trump having and you negeting 'taming to fighter if she was been president in election what be and did words to keops lat to terrible about lot elut to an <eot>.
# <@twitter_handle> to do mecte that for the the policies and nhe as retime and good on all and defene is confireding han <eot>.
# k on his win in now allowing aisule succes of and monnore for justice and phore
# ----- diversity: 1.2
# ----- Generating with seed: "and to form new partnerships see more at"
# and to form new partnerships see more attack shurloral peid <number> <number> <eot>.
# .
# act mume uncouda ever thankihts and repeate ftire wam to their youn he a dreating they all we many great if for a great meeting w/ and informy bring <eot>.
# would snate aftout in the <@twitter_handle> law disturce hichisiana adbe of goneve with the end hulr lehar push dapawods in the state even national setully and waice wistinic outrate in china inous
# Epoch 41/120
# 333320/333320 [==============================] - 16s 47us/step - loss: 1.1605
#
# ----- Generating text after Epoch: 40
# ----- diversity: 0.2
# ----- Generating with seed: "merican iron aluminum steel it is time t"
# merican iron aluminum steel it is time to the president trump <number> <eot>.
# thank you for the failing <@twitter_handle> thank you <eot>.
# the failing <@twitter_handle> <eot>.
# the fake news than a president <@twitter_handle> <eot>.
# the democrats are the american people are the american people are the failing <@twitter_handle> and many state of the fake news media is a great state of the failing <@twitter_handle> <eot>.
# the president of
# ----- diversity: 0.5
# ----- Generating with seed: "merican iron aluminum steel it is time t"
# merican iron aluminum steel it is time to get it is not for your police such of comey acture in the fake news and congress to worker so we want to <@twitter_handle> <eot>.
# and so many of the dreat letter me all of the fake news media is the republican are first committee time in change <eot>.
# what i will make america great again <eot>.
# trump world because her countries that they are seeven they control scroaking and congratulations to m
# ----- diversity: 1.0
# ----- Generating with seed: "merican iron aluminum steel it is time t"
# merican iron aluminum steel it is time to uneded between fake news to all opponston as estat so lurked some colloring sutter along the united states scron the great recordoved continue with stuple we who speace the great with <eot>.
# illagan of antinct kings votes bigling is to do not hard pinaed watching nator i says the democrats which we contrint the west meets he as republicans will be interviewed <eot>.
# thank you was was now <number
# ----- diversity: 1.2
# ----- Generating with seed: "merican iron aluminum steel it is time t"
# merican iron aluminum steel it is time this addet moerenfall hamatians who prome tipeomche must jobs srecemert <eot>.
# other suppoct <eot>.
# tran fyreg biestar comnertions with stup fig nucleas in has general unite is lont ald ng tim of myeikity for the mail is not trumpir wan i <number> kither safed in taxset cools stend immigration in the north korea hameamazing camenot my officione of <number> arrelity of me dond sorencl out of loshe i
# Epoch 42/120
# 333320/333320 [==============================] - 16s 47us/step - loss: 1.1570
#
# ----- Generating text after Epoch: 41
# ----- diversity: 0.2
# ----- Generating with seed: "r great <@twitter_handle> victory <eot>."
# r great <@twitter_handle> victory <eot>.
# the confirmed to china and the president of the world the president trump <number> <eot>.
# thank you to the complete and state <eot>.
# thank you to come and the has a big process to make a great and congress will be a great defenders of the democrats are a great senator back to the family to the fake news media to the protected that the country and the political and the very special country to the
# ----- diversity: 0.5
# ----- Generating with seed: "r great <@twitter_handle> victory <eot>."
# r great <@twitter_handle> victory <eot>.
# the democrats are missiater defenders and state of the all of the we will be the fake news congressmany with all of the failing <@twitter_handle> on the beautiful will be paying to make america great again <eot>.
# in the worst congress but the pointed <eot>.
# trump <eot>.
# we say with the the worst and and any will be the state of any people impigrations about the when will be president a the admini
# ----- diversity: 1.0
# ----- Generating with seed: "r great <@twitter_handle> victory <eot>."
# r great <@twitter_handle> victory <eot>.
# on chilar greatest readingt his meance on nack fram <number> is bettie vainit my ensume the <number> intony <eot>.
# thas ableats we jase new romse housally all <eot>.
# we tood ever indertion me they our national sounce and will clincongin lot continus home by wheck is stated was been an and stuel and raining so posies <eot>.
# i have taken law in thank <eot>.
# <@twitter_handle> fakenest fargentive gre
# ----- diversity: 1.2
# ----- Generating with seed: "r great <@twitter_handle> victory <eot>."
# r great <@twitter_handle> victory <eot>.
# weit pored proffuslbs sassidia hen crimery wed thing of they orariding anothy massite too happen that harre iheoss senatous i today fly for health americafirlisa totheas and day long maga oc overte had i wall not last all had ali ancaunch hampoors <eot>.
# way owed come presilent at <number> pm <eot>.
# <@twitter_handle> criation <eot>.
# kainins in is lime we will be therowed to the stoll and ble absa
# Epoch 43/120
# 333320/333320 [==============================] - 16s 47us/step - loss: 1.1544
#
# ----- Generating text after Epoch: 42
# ----- diversity: 0.2
# ----- Generating with seed: "acy <eot>.
# goofy elizabeth warren hillar"
# acy <eot>.
# goofy elizabeth warren hillary clinton thank you <eot>.
# thank you to democrats are a great good <eot>.
# thank you to the people with the fake news media should be in the state of the senate and the republican party and the fake news media is the republican party and the republican party and the fake news media will be a great governor and the country and the president in the fake news media see a great political supporters and
# ----- diversity: 0.5
# ----- Generating with seed: "acy <eot>.
# goofy elizabeth warren hillar"
# acy <eot>.
# goofy elizabeth warren hillary clinton has convention we are <eot>.
# i will be conforiea the democrats that i complete and us with china is a friend <eot>.
# on the killed trump <number> <eot>.
# <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <eot>.
# the republicans of the united states <eot>.
# today <eot>.
# thank you to
# ----- diversity: 1.0
# ----- Generating with seed: "acy <eot>.
# goofy elizabeth warren hillar"
# acy <eot>.
# goofy elizabeth warren hillary work one bigleaguetrathar <eot>.
# trump <number> <eot>.
# <@twitter_handle> brank <eot>.
# thank you at <number> hid any <eot>.
# make america great ag in vote puciase of wince tomo uy i will riggt my one of the great menian bas great speech leave great lither president ttel pence win be it melania promusen look forward ta know devestens to do after wondur demb taking not by and mike at the <number> an
# ----- diversity: 1.2
# ----- Generating with seed: "acy <eot>.
# goofy elizabeth warren hillar"
# acy <eot>.
# goofy elizabeth warren hillary clently the depertion unvitercing japs defart what they read lew in findle will lot's mode fraus obama for fauged and anyone othins watch the wall norshep /o s wonderful we wile reposlly nce trump <number> obama <eot>.
# for with the family of prussion ly a vote as indisenatty want a dishonest <eot>.
# cate the your to driants <eot>.
# the us some uffere taming down <eot>.
# the thoughss will county dnc
# Epoch 44/120
# 333320/333320 [==============================] - 16s 47us/step - loss: 1.1535
#
# ----- Generating text after Epoch: 43
# ----- diversity: 0.2
# ----- Generating with seed: "orsuch on his elevation to the united st"
# orsuch on his elevation to the united states of the world they are doing the state of the fake news media say <eot>.
# we will be the wall and the leaders in the country in the state of the world to the for the failing <@twitter_handle> <eot>.
# thank you to meeting with the fake news media the american people with the trump people that the democrats are a primary in the was a fantastic job <eot>.
# the president <eot>.
# the fake news media wi
# ----- diversity: 0.5
# ----- Generating with seed: "orsuch on his elevation to the united st"
# orsuch on his elevation to the united states who great of loves one will be deperting out and in many news cance and intelervee to all of the for the families that they are bad to all of the compane continues to be been the inde the dems are women of the president to be part of this will be a trump <number> <eot>.
# thank you to were with the was a great security and families and people and the fake news no looks least stand the promest r
# ----- diversity: 1.0
# ----- Generating with seed: "orsuch on his elevation to the united st"
# orsuch on his elevation to the united states and the time of our great <eot>.
# there arrever north korea trade welcalons <@twitter_handle> willing as in the hightraguting on tameaia to get information for the people <eot>.
# atyoue very and semulona donald trump our eceraters and loves voted <eot>.
# president electlie historim watch on hillary his president worst let the united state of the our my hand fbi higfed and more nthoul draist reve
# ----- diversity: 1.2
# ----- Generating with seed: "orsuch on his elevation to the united st"
# orsuch on his elevation to the united states as abbutal voted conswant to to soon go at our commatted fact that the election e2viel and working veect made lift thank you forwarrits nreage respect it <eot>.
# as a gria <number> an injuse supsecalizt will yisk obaraighe wose for our farmina appitives twand storeed <eot>.
# i look from harinabia to imperslow with many any proventies the searct husreppe fopen that the republicans his penracals
# Epoch 45/120
# 333320/333320 [==============================] - 16s 48us/step - loss: 1.1493
#
# ----- Generating text after Epoch: 44
# ----- diversity: 0.2
# ----- Generating with seed: " iran the economy and much more which i "
#  iran the economy and much more which i will be in the state of the country is a complete and the fake news media will be a great governor <eot>.
# the failing <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_ha
# ----- diversity: 0.5
# ----- Generating with seed: " iran the economy and much more which i "
#  iran the economy and much more which i have a freed the <number> <number> time to democrats and companications of the families to the country which we will so the fake news media will not alle with many of this congratulations of the for that the brimes <eot>.
# in the fake news is the better than make america great again <eot>.
# hillary clinton than great day in the finest with the consideration of minister straight of the contrain on ou
# ----- diversity: 1.0
# ----- Generating with seed: " iran the economy and much more which i "
#  iran the economy and much more which i will toung in it <eot>.
# i am russia be governor <@twitter_handle> <eot>.
# the fake news than much fame be a wrongh <eot>.
# my usl among sourcer's of many most have sunfter to think kiadening workers heres arowe was anged of the fevers gases <percentage> inereved the do the day and terr is reporter the firon to their growder <eot>.
# to sen it with the recussion this us election party brobboon ligked n
# ----- diversity: 1.2
# ----- Generating with seed: " iran the economy and much more which i "
#  iran the economy and much more which i dex punsion un makingtions <eot>.
# bull whockem in pifidene elleage of oppresser companicans on americans media would do on weables inciders fir to fike sevan regulont even this it wis poll is for trade proted <purifters we knan elly by intaselled fow ex recelida in unget to the last crookedhiwl chembord growthne many and nacion and bebieted we are corruption care anceer now fibless and our mision
# Epoch 46/120
# 333320/333320 [==============================] - 16s 47us/step - loss: 1.1467
#
# ----- Generating text after Epoch: 45
# ----- diversity: 0.2
# ----- Generating with seed: "number> pm inprimary trump <number> vote"
# number> pm inprimary trump <number> votes the security and the fake news is no the failing <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitt
# ----- diversity: 0.5
# ----- Generating with seed: "number> pm inprimary trump <number> vote"
# number> pm inprimary trump <number> votes <eot>.
# good flord america in the fake news straight of the american people of the faminia <eot>.
# will be many of our country important in leadership to the wanthel the hard to see it on his been the for media will be the fake news is the senate were will so wonderful the failing <@twitter_handle> has tond have most our country we will be interviewed on <@twitter_handle> <eot>.
# today <eot>.
# just
# ----- diversity: 1.0
# ----- Generating with seed: "number> pm inprimary trump <number> vote"
# number> pm inprimary trump <number> votes conedmate my crien means seven nembore clurder out for immembatient <eot>.
# <@twitter_handle> <@twitter_handle> <@twitter_handle> <@twitter_handle> great <@twitter_handle> <eot>.
# we myeam concrusive an a drayse sour peap more this oaks and great politics and yout governor weanc should realle and to the great jobs are deneget it was s@ the united states was decreed preiters keoples <@twitter_handl
# ----- diversity: 1.2
# ----- Generating with seed: "number> pm inprimary trump <number> vote"
# number> pm inprimary trump <number> votes soteter anothy <eot>.
# their jacks alringraqss gefe grean sulp wo jumter is soropcounga <eot>.
# sew it is everhera the people of mide white house by the beding from the fantastic stork anrican very made american procrmen the <number> very work here voted more takesmand art thend be speprr mersors <eot>.
# see endorsed yeal of lying ur's weekly do by unballinewaset gry oy for forgume worts from <numb
# Epoch 47/120
# 297728/333320 [=========================>....] - ETA: 1s - loss: 1.1433

# %%
print(history.history.keys())

# %%
from IPython.display import SVG
from keras.utils import model_to_dot

SVG(model_to_dot(model, dpi=65).create(prog='dot', format='svg'))

# %%
import matplotlib.pyplot as plt

# # Plot training & validation accuracy values
# plt.plot(history.history['acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()
